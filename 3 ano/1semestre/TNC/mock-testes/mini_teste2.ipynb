# %% [markdown]
# Dada a chave pública ElGamal (p, r, b)=( 3658826191 , 6 , 1195572158 ), a decifração de ( 3361123851 , 3341676695 ) é

# %%
(p, r, b)=( 3658826191 , 6 , 1195572158 )
Zp = IntegerModRing(p)
r = Zp(r)
b = Zp(b)
gama, delta = Zp(3361123851) , Zp(3341676695) 
a = discrete_log(b,r)
(1/gama)^a*delta

# %% [markdown]
# Pergunta 2
# Para p = 62299 , indique exatamente quais dos seguintes naturais são raizes primitivas de p:

# %%
p = 62299
Zp = IntegerModRing(p)
a1, a2, a3, a4 = Zp(12419), Zp(48559), Zp(51717), Zp(4673)
multiplicative_order(a1), multiplicative_order(a2), multiplicative_order(a3), multiplicative_order(a4)

# %% [markdown]
# Pergunta 3
# Dada a chave pública ElGamal (p, r, b)=( 881133293775745811 , 2 , 735348618468858018 ) a cifração de mens=1234, com o parâmetro aleatório k= 347890944295022020 , é (gama, delta) =

# %%
(p, r, b)=( 881133293775745811 , 2 , 735348618468858018 )
mens=1234
k= 347890944295022020
Zp = IntegerModRing(p)
r = Zp(r)
b = Zp(b)
gama , delta = r^k , mens*b^k
gama , delta

# %% [markdown]
# Considere o primo p= 5152356175582822333 e a raiz primitiva r= 15 de p. O índice de b= 4052323580690504301 na base r é igual a

# %%
p = 5152356175582822333
r = 15
b = 4052323580690504301
Zp = IntegerModRing(p)
r =  Zp(r)
b = Zp(b)
discrete_log(b, r)

# %% [markdown]
# Para n = 37127 , indique exatamente quais das seguintes bases n é pseudo primo de Euler:

# %%
n = 37127 
Zn = IntegerModRing(n)
b1, b2, b3, b4 = Zn(25722), Zn(37126), Zn(35773), Zn(19195)
b1^((n-1)//2), b2^((n-1)//2), b3^((n-1)//2), b4^((n-1)//2), jacobi_symbol(b1, n), jacobi_symbol(b2, n), jacobi_symbol(b3, n), jacobi_symbol(b4, n)

# %% [markdown]
# =================================================================================================================

# %% [markdown]
# Dada a chave pública ElGamal (p, r, b)=( 3137291693 , 2 , 424669327 ), a decifração de ( 870116626 , 366464538 ) é

# %%
(p, r, b)= (3137291693 , 2 , 424669327)
(gama , delta) = (870116626 , 366464538)
Zp = IntegerModRing(p)
r = Zp(r)
b = Zp(b)
(gama , delta) = (Zp(870116626) , Zp(366464538))
a = discrete_log(b,r)
(1/gama)^a*delta

# %% [markdown]
# Pergunta 2
# Dada a chave pública ElGamal (p, r, b)=( 15079807463219498269 , 6 , 11411606490027937682 ) a cifração de mens=1234, com o parâmetro aleatório k= 8079527706493109209 , é (gama, delta) =

# %%
(p, r, b)=(15079807463219498269 , 6 , 11411606490027937682)
mens=1234
k= 8079527706493109209 
Zp = IntegerModRing(p)
r = Zp(r)
b = Zp(b)
gama , delta = r^k , mens*b^k
gama , delta

# %% [markdown]
# Considere o primo p= 17326967367196526087 e a raiz primitiva r= 5 de p. O índice de b= 2626655245610212378 na base r é igual a

# %%
p = 17326967367196526087
r = 5
b = 2626655245610212378

Zp = IntegerModRing(p)
r = Zp(r)
b = Zp(b)
discrete_log(b,r)

# %% [markdown]
# Pergunta 4
# Para n = 125549 , indique exatamente quais das seguintes bases n é pseudo primo de Euler:

# %%
n = 125549
Zn = IntegerModRing(n)
a1, a2, a3, a4 = Zn(117137), Zn(116108), Zn(94440), Zn(125548)
a1^((n-1)//2), a2^((n-1)//2), a3^((n-1)//2), a4^((n-1)//2), jacobi_symbol(a1, n), jacobi_symbol(a2, n), jacobi_symbol(a3, n), jacobi_symbol(a4, n)

# %% [markdown]
# Pergunta 5
# Para p = 62299 , indique exatamente quais dos seguintes naturais são raizes primitivas de p:

# %%
p = 62299
Zp = IntegerModRing(p)
a1, a2, a3, a4 = Zp(4673),  Zp(48559),  Zp(51717),  Zp(12419)
multiplicative_order(a1), multiplicative_order(a2), multiplicative_order(a3), multiplicative_order(a4)

# %% [markdown]
# =================================================================================================================

# %% [markdown]
# Dada a chave pública ElGamal (p, r, b)=( 3118757659 , 2 , 1414981525 ), a decifração de ( 1831641820 , 1936870489 ) é

# %%
(p, r, b)=( 3118757659 , 2 , 1414981525 ) 
gama, delta = (1831641820 , 1936870489)
Zp = IntegerModRing(p)
r = Zp(r)
b = Zp(b)
gama, delta = Zp(1831641820) ,Zp(1936870489)
a = discrete_log(b,r)
(1/gama)^a*delta

# %% [markdown]
# Considere o primo p= 12889067875217192513 e a raiz primitiva r= 3 de p. O índice de b= 10362465250480467630 na base r é igual a

# %%
p = 12889067875217192513
r = 3 
b = 10362465250480467630
Zp = IntegerModRing(p)
r = Zp(r)
b = Zp(b)
discrete_log(b,r)

# %% [markdown]
# Dada a chave pública ElGamal (p, r, b)=( 10323805730680867973 , 2 , 8510132500452235162 ) a cifração de mens=1234, com o parâmetro aleatório k= 1459266684476228832 , é (gama, delta) =

# %%
(p, r, b)=(10323805730680867973 , 2 , 8510132500452235162)
mens = 1234
k = 1459266684476228832
Zp = IntegerModRing(p)
r = Zp(r)
b = Zp(b)

gama, delta = r^k, mens*b^k
gama, delta

# %% [markdown]
# Pergunta 4
# Para p = 16921 , indique exatamente quais dos seguintes naturais são raizes primitivas de p:

# %%
p = 16921
Zp = IntegerModRing(p)
a1, a2, a3, a4 = Zp(5988), Zp(3631), Zp(9168), Zp(8518)
multiplicative_order(a1), multiplicative_order(a2), multiplicative_order(a3), multiplicative_order(a4)

# %% [markdown]
# Para n = 108673 , indique exatamente quais das seguintes bases n é pseudo primo de Euler:

# %%
n = 108673
Zn = IntegerModRing(n)
a1, a2,a3,a4 = Zn(1158), Zn(60617), Zn(72397), Zn(56254)
a1^((n-1)//2), a2^((n-1)//2), a3^((n-1)//2), a4^((n-1)//2), jacobi_symbol(a1,n), jacobi_symbol(a2,n), jacobi_symbol(a3,n), jacobi_symbol(a4,n)

# %% [markdown]
# =================================================================================================================

# %% [markdown]
# Pergunta 1
# Para n = 91657 , indique exatamente quais das seguintes bases n é pseudo primo de Euler:

# %%
n = 91657
Zn = IntegerModRing(n)
a1, a2, a3, a4 = Zn(5252), Zn(30614), Zn(42061), Zn(46334)
a1^((n-1)//2), a2^((n-1)//2), a3^((n-1)//2), a4^((n-1)//2), jacobi_symbol(a1,n),  jacobi_symbol(a2,n),  jacobi_symbol(a3,n),  jacobi_symbol(a4,n)

# %% [markdown]
# Considere o primo p= 14429568937645027039 e a raiz primitiva r= 6 de p. O índice de b= 2552336463867099405 na base r é igual a

# %%
p = 14429568937645027039
r = 6
b = 2552336463867099405
Zp = IntegerModRing(p)
r = Zp(r)
b = Zp(b)

discrete_log(b,r)

# %% [markdown]
# Dada a chave pública ElGamal (p, r, b)=( 3658826191 , 6 , 1195572158 ), a decifração de ( 3361123851 , 3341676695 ) é

# %%
(p, r, b)=(3658826191 , 6 , 1195572158)
gama, delta = (3361123851 , 3341676695)

Zp = IntegerModRing(p)
r = Zp(r)
b = Zp(b)
gama, delta = Zp(3361123851) , Zp(3341676695)

a = discrete_log(b,r)
(1/gama)^a*delta

# %% [markdown]
# Pergunta 4
# Dada a chave pública ElGamal (p, r, b)=( 881133293775745811 , 2 , 735348618468858018 ) a cifração de mens=1234, com o parâmetro aleatório k= 347890944295022020 , é (gama, delta) =

# %%
(p, r, b)=(881133293775745811 , 2 , 735348618468858018)
mens = 1234
k= 347890944295022020
Zp = IntegerModRing(p)
r = Zp(r)
b = Zp(b)
gama , delta = r^k, mens*b^k
gama , delta

# %% [markdown]
# Para p = 44491 , indique exatamente quais dos seguintes naturais são raizes primitivas de p:

# %%
p = 44491
Zp= IntegerModRing(p)

a1, a2, a3,a4 = Zp(535), Zp(13441), Zp(29091), Zp(2954)
multiplicative_order(a1), multiplicative_order(a2), multiplicative_order(a3), multiplicative_order(a4)

# %% [markdown]
# =================================================================================================================

# %% [markdown]
# Pergunta 1
# Dada a chave pública ElGamal (p, r, b)=( 5018551989374027857 , 10 , 2233668194167585828 ) a cifração de mens=1234, com o parâmetro aleatório k= 3603252134596293054 , é (gama, delta) =

# %%
(p, r, b)=( 5018551989374027857 , 10 , 2233668194167585828 )
mens = 1234
k = 3603252134596293054
Zp = IntegerModRing(p)
r = Zp(r)
b = Zp(b)
gama, delta = r^k, mens*b^k
gama, delta

# %% [markdown]
# Dada a chave pública ElGamal (p, r, b)=( 1526602603 , 5 , 1519554338 ), a decifração de ( 818055310 , 1500887421 ) é

# %%
(p, r, b)=(1526602603 , 5 , 1519554338)
gama , delta = (818055310 , 1500887421)
Zp = IntegerModRing(p)
r = Zp(r)
b = Zp(b)
gama, delta = Zp(818055310), Zp(1500887421)
a = discrete_log(b,r)
(1/gama)^a*delta

# %% [markdown]
# Pergunta 3
# Para p = 16921 , indique exatamente quais dos seguintes naturais são raizes primitivas de p:

# %%
p = 16921
Zp = IntegerModRing(p)
a1, a2, a3, a4 = Zp(8518), Zp(3631), Zp(5988), Zp(9168)
multiplicative_order(a1), multiplicative_order(a2), multiplicative_order(a3), multiplicative_order(a4)

# %% [markdown]
# Considere o primo p= 5152356175582822333 e a raiz primitiva r= 15 de p. O índice de b= 4052323580690504301 na base r é igual a

# %%
p = 5152356175582822333
r = 15
b = 4052323580690504301
Zp = IntegerModRing(p)
r = Zp(r)
b = Zp(b)
discrete_log(b,r)

# %% [markdown]
# Pergunta 5
# Para n = 73817 , indique exatamente quais das seguintes bases n é pseudo primo de Euler:

# %%
n = 73817
Zn = IntegerModRing(n)
a1, a2,a3 ,a4 = Zn(823), Zn(36239), Zn(57969), Zn(29870)
a1^((n-1)//2), a2^((n-1)//2), a3^((n-1)//2), a4^((n-1)//2), jacobi_symbol(a1,n), jacobi_symbol(a2,n), jacobi_symbol(a3,n), jacobi_symbol(a4,n)

# %% [markdown]
# =================================================================================================================

# %% [markdown]
# Pergunta 1
# Dada a chave pública ElGamal (p, r, b)=( 12461140735080009251 , 2 , 947414031569586861 ) a cifração de mens=1234, com o parâmetro aleatório k= 2079034129096147812 , é (gama, delta) =

# %%
(p, r, b)=(12461140735080009251 , 2 , 947414031569586861)
mens = 1234
k = 2079034129096147812
Zp = IntegerModRing(p)
r = Zp(r)
b = Zp(b)
gama, delta = r^k, mens*b^k
gama, delta

# %% [markdown]
# Pergunta 2
# Para n = 37127 , indique exatamente quais das seguintes bases n é pseudo primo de Euler:

# %%
n = 37127
Zn = IntegerModRing(n)
a1, a2, a3, a4 = Zn(35773), Zn(37126), Zn(19195), Zn(25722)
a1^((n-1)//2), a2^((n-1)//2), a3^((n-1)//2), a4^((n-1)//2), jacobi_symbol(a1,n), jacobi_symbol(a2,n), jacobi_symbol(a3,n), jacobi_symbol(a4,n)

# %% [markdown]
# Pergunta 3
# Para p = 16921 , indique exatamente quais dos seguintes naturais são raizes primitivas de p:

# %%
p = 16921
Zp = IntegerModRing(p)
a1, a2, a3, a4 = Zp(5988), Zp(9168), Zp(3631), Zp(8518)
multiplicative_order(a1), multiplicative_order(a2), multiplicative_order(a3), multiplicative_order(a4)

# %% [markdown]
# Considere o primo p= 4742136830611450301 e a raiz primitiva r= 3 de p. O índice de b= 713204825788199601 na base r é igual a

# %%
p = 4742136830611450301
r = 3
b = 713204825788199601
Zp = IntegerModRing(p)
r = Zp(r)
b = Zp(b)
discrete_log(b, r)

# %% [markdown]
# Dada a chave pública ElGamal (p, r, b)=( 1262804383 , 6 , 676027718 ), a decifração de ( 932022663 , 910483139 ) é

# %%
(p, r, b)=(1262804383 , 6 , 676027718)
gama, delta = (932022663 , 910483139)

Zp = IntegerModRing(p)
r = Zp(r)
b = Zp(b)
gama, delta = Zp(932022663), Zp(910483139)
a = discrete_log(b,r)

((1/gama)^a*delta)

# %% [markdown]
# ==================================================================================================================================================

# %% [markdown]
# Pergunta 1
# Dada a chave pública ElGamal (p, r, b)=( 15079807463219498269 , 6 , 11411606490027937682 ) a cifração de mens=1234, com o parâmetro aleatório k= 8079527706493109209 , é (gama, delta) =

# %%
(p, r, b)=(15079807463219498269 , 6 , 11411606490027937682)
mens = 1234
k = 8079527706493109209
Zp = IntegerModRing(p)
r = Zp(r)
b = Zp(b)
gama, delta = r^k, mens*b^k
gama, delta

# %% [markdown]
# Dada a chave pública ElGamal (p, r, b)=( 1526602603 , 5 , 1519554338 ), a decifração de ( 818055310 , 1500887421 ) é

# %%
(p, r, b)=(1526602603 , 5 , 1519554338)
gama, delta = (818055310 , 1500887421)
Zp = IntegerModRing(p)
r = Zp(r)
b = Zp(b)
gama, delta = Zp(818055310), Zp(1500887421)
a = discrete_log(b,r)
(1/gama)^a*delta

# %% [markdown]
# Pergunta 3
# Para p = 53309 , indique exatamente quais dos seguintes naturais são raizes primitivas de p:

# %%
p = 53309
Zp = IntegerModRing(p)
a1, a2, a3, a4 = Zp(26012), Zp(27227), Zp(19698), Zp(49356)
multiplicative_order(a1), multiplicative_order(a2), multiplicative_order(a3), multiplicative_order(a4)

# %% [markdown]
# Considere o primo p= 17326967367196526087 e a raiz primitiva r= 5 de p. O índice de b= 2626655245610212378 na base r é igual a

# %%
p = 17326967367196526087
r = 5
b = 2626655245610212378
Zp = IntegerModRing(p)
r = Zp(r)
b = Zp(b)
discrete_log(b,r)

# %% [markdown]
# Pergunta 5
# Para n = 93991 , indique exatamente quais das seguintes bases n é pseudo primo de Euler:

# %%
n = 93991
Zn = IntegerModRing(n)
a1, a2, a3, a4 = Zn(11822), Zn(1460), Zn(55273), Zn(85063)
a1^((n-1)//2), a2^((n-1)//2), a3^((n-1)//2), a4^((n-1)//2), jacobi_symbol(a1,n), jacobi_symbol(a2,n), jacobi_symbol(a3,n), jacobi_symbol(a4,n)

# %% [markdown]
# Dada a chave pública ElGamal (p, r, b)=( 2988637943 , 5 , 2269369487 ), a decifração de ( 2046586184 , 387673328 ) é

# %%
(p, r, b)=(2988637943 , 5 , 2269369487)
gama, delta = (2046586184 , 387673328)
Zp = IntegerModRing(p)
r = Zp(r)
b = Zp(b)
gama, delta = Zp(2046586184), Zp(387673328)
a = discrete_log(b,r)
(1/gama)^a*delta

# %% [markdown]
# Pergunta 2
# Dada a chave pública ElGamal (p, r, b)=( 3934190361409688047 , 6 , 3486764723692982813 ) a cifração de mens=1234, com o parâmetro aleatório k= 3269422753800136199 , é (gama, delta) =

# %%
(p, r, b)=( 3934190361409688047 , 6 , 3486764723692982813 )
mens = 1234
k= 3269422753800136199
Zp = IntegerModRing(p)
r = Zp(r)
b = Zp(b)
gama, delta = r^k, mens*b^k
gama, delta

# %% [markdown]
# Pergunta 3
# Para n = 66427 , indique exatamente quais das seguintes bases n é pseudo primo de Euler:

# %%
n = 66427
Zn = IntegerModRing(n)
a1, a2, a3, a4 = Zn(27397), Zn(64397), Zn(43538), Zn(2485)
a1^((n-1)//2), a2^((n-1)//2), a3^((n-1)//2), a4^((n-1)//2), jacobi_symbol(a1,n),  jacobi_symbol(a2,n),  jacobi_symbol(a3,n),  jacobi_symbol(a4,n)

# %% [markdown]
# Pergunta 4
# Para p = 53309 , indique exatamente quais dos seguintes naturais são raizes primitivas de p:

# %%
p = 53309
Zp = IntegerModRing(p)
a1, a2, a3, a4 = Zp(49356), Zp(26012), Zp(19698), Zp(27227)
multiplicative_order(a1), multiplicative_order(a2), multiplicative_order(a3), multiplicative_order(a4)

# %% [markdown]
# Considere o primo p= 12840760258065626077 e a raiz primitiva r= 5 de p. O índice de b= 4600833455292774143 na base r é igual

# %%
p = 12840760258065626077
r = 5
b = 4600833455292774143
Zp = IntegerModRing(p)
r = Zp(r)
b = Zp(b)
discrete_log(b,r)

# %% [markdown]
# ====================================================================================================================================================

# %% [markdown]
# Pergunta 1
# Para n = 73817 , indique exatamente quais das seguintes bases n é pseudo primo de Euler:

# %%
n = 73817
Zn = IntegerModRing(n)
a1, a2, a3, a4 = Zn(57969), Zn(36239), Zn(29870), Zn(823)
a1^((n-1)//2), a2^((n-1)//2), a3^((n-1)//2), a4^((n-1)//2), jacobi_symbol(a1,n),  jacobi_symbol(a2,n),  jacobi_symbol(a3,n), jacobi_symbol(a4,n)

# %% [markdown]
# Pergunta 2
# Para p = 44491 , indique exatamente quais dos seguintes naturais são raizes primitivas de p:

# %%
p = 44491
Zp = IntegerModRing(p)
a1, a2, a3, a4 = Zp(29091), Zp(2954), Zp(535), Zp(13441)
multiplicative_order(a1), multiplicative_order(a2), multiplicative_order(a3), multiplicative_order(a4)

# %% [markdown]
# Dada a chave pública ElGamal (p, r, b)=( 1262804383 , 6 , 676027718 ), a decifração de ( 932022663 , 910483139 ) é

# %%
(p, r, b)=( 1262804383 , 6 , 676027718 )
gama, delta = ( 932022663 , 910483139 )
Zp = IntegerModRing(p)
r = Zp(r)
b = Zp(b)
gama, delta = Zp(932022663), Zp( 910483139)
a = discrete_log(b,r)
(1/gama)^a*delta

# %% [markdown]
# Pergunta 4
# Dada a chave pública ElGamal (p, r, b)=( 10323805730680867973 , 2 , 8510132500452235162 ) a cifração de mens=1234, com o parâmetro aleatório k= 1459266684476228832 , é (gama, delta) =

# %%
(p, r, b)=( 10323805730680867973 , 2 , 8510132500452235162 )
mens = 1234
k= 1459266684476228832
Zp = IntegerModRing(p)
r = Zp(r)
b = Zp(b)
gama, delta = r^k, mens*b^k
gama, delta

# %% [markdown]
# Considere o primo p= 4742136830611450301 e a raiz primitiva r= 3 de p. O índice de b= 713204825788199601 na base r é igual a

# %%
p= 4742136830611450301
r = 3 
b= 713204825788199601
Zp = IntegerModRing(p)
r = Zp(r)
b = Zp(b)
discrete_log(b,r)
